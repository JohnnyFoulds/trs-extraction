# %% [markdown]
# # 01-01 : Nougat OCR
#
# Perform a basic test of OCR on a PDF file using the Nougat OCR engine.

# %%
import os
import subprocess
import sys

# %% [markdown]
# ## 1. Configuration

# %%
data_path = '../../../data'
test_path = f'{data_path}/test'
samples_path = f'{test_path}/sample_pdf'

output_path = f'{data_path}/output'
output_pdf_path = f'{output_path}/sample_pdf'
current_output_path = f'{output_pdf_path}/nougat'

# %% [markdown]
# ## 2. Get Sample PDF List

# %%
# get a list of all the pdf files in the sample_pdf directory
pdf_files = os.listdir(samples_path)
pdf_files = [f for f in pdf_files if f.endswith('.pdf')]
pdf_files.sort()

# show the list of pdf files
print('List of PDF files:')
print(pdf_files)
# Out:
# List of PDF files:
# ['01.pdf', '02.pdf', '03.pdf', '04.pdf', '05.pdf']

# %% [markdown]
# ## 3. Basic Test

# %%
# get the absolute path the the pdf file
pdf_file = os.path.abspath(f'{samples_path}/{pdf_files[4]}')
print(f'Absolute path to the first PDF file: {pdf_file}')

# call nougat
# !nougat {pdf_file} -o {current_output_path} -m 0.1.0-base --recompute
# Out:
# Absolute path to the first PDF file: /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/05.pdf
# /home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/nougat/model.py:437: UserWarning: var(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1831.)
#   return torch.var(self.values, 1) / self.values.shape[1]
# WARNING:root:Found repetitions in sample 0
# INFO:root:Processing file /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/05.pdf with 1 pages
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.45s/it]

# %% [markdown]
# ## 4. Process All PDF Files

# %%
for file in pdf_files:
    # get the absolute path to the pdf file
    pdf_file = os.path.abspath(f'{samples_path}/{file}')
    print(f'Absolute path to the PDF file: {pdf_file}')

    # call nougat
    subprocess.run(['nougat', pdf_file, '-o', current_output_path, '-m', '0.1.0-base', '--recompute'])
# Out:
# Absolute path to the PDF file: /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/01.pdf
# /home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|          | 0/1 [00:00<?, ?it/s]/home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/nougat/model.py:437: UserWarning: var(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1831.)
#   return torch.var(self.values, 1) / self.values.shape[1]
# INFO: likely hallucinated title at the end of the page: ### 7.4.
# INFO:root:Processing file /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/01.pdf with 7 pages
# 100%|██████████| 1/1 [00:06<00:00,  6.61s/it]
# -> Cannot close object, library is destroyed. This may cause a memory leak!
# -> Cannot close object, library is destroyed. This may cause a memory leak!
# Absolute path to the PDF file: /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/02.pdf
# /home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|          | 0/1 [00:00<?, ?it/s]/home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/nougat/model.py:437: UserWarning: var(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1831.)
#   return torch.var(self.values, 1) / self.values.shape[1]
# WARNING:root:Found repetitions in sample 0
# INFO:root:Processing file /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/02.pdf with 1 pages
# 100%|██████████| 1/1 [00:01<00:00,  1.47s/it]
# Absolute path to the PDF file: /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/03.pdf
# /home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|          | 0/1 [00:00<?, ?it/s]/home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/nougat/model.py:437: UserWarning: var(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1831.)
#   return torch.var(self.values, 1) / self.values.shape[1]
# WARNING:root:Found repetitions in sample 0
# INFO:root:Processing file /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/03.pdf with 1 pages
# 100%|██████████| 1/1 [00:01<00:00,  1.75s/it]
# Absolute path to the PDF file: /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/04.pdf
# /home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# WARNING:pypdf._reader:Ignoring wrong pointing object 6 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 8 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 10 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 16 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 18 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 33 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 37 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 39 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 42 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 44 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 106 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 108 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 110 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 112 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 139 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 156 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 185 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 238 0 (offset 0)
#   0%|          | 0/4 [00:00<?, ?it/s]/home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/nougat/model.py:437: UserWarning: var(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1831.)
#   return torch.var(self.values, 1) / self.values.shape[1]
# INFO:root:Processing file /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/04.pdf with 24 pages
# 100%|██████████| 4/4 [00:35<00:00,  8.86s/it]
# -> Cannot close object, library is destroyed. This may cause a memory leak!
# Absolute path to the PDF file: /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/05.pdf
# /home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|          | 0/1 [00:00<?, ?it/s]/home/johnny/swan/miniconda3/envs/trs-extraction/lib/python3.11/site-packages/nougat/model.py:437: UserWarning: var(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1831.)
#   return torch.var(self.values, 1) / self.values.shape[1]
# WARNING:root:Found repetitions in sample 0
# INFO:root:Processing file /home/johnny/swan/code/trs-extraction/data/test/sample_pdf/05.pdf with 1 pages
# 100%|██████████| 1/1 [00:01<00:00,  1.46s/it]
